# %% [markdown]
# <a href="https://colab.research.google.com/github/asheta66/Data-Mining-2/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import data set**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('ClevlandDataSet.xlsx')
df.head()
# Out:
#    Age  Sex  CP  Trestbps  Chol  fbs  restecg  Thalach  Exang  Oldpeak  Slop  \
# 0   63    1   1       145   233    1        2      150      0      2.3     3
# 1   67    1   4       160   286    0        2      108      1      1.5     2
# 2   67    1   4       120   229    0        2      129      1      2.6     2
# 3   37    1   3       130   250    0        0      187      0      3.5     3
# 4   41    0   2       130   204    0        2      172      0      1.4     1
#
#    CA  thal  Class
# 0   0     6      0
# 1   3     3      2
# 2   2     7      1
# 3   0     3      0
# 4   0     3      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       297 non-null    int64
#  1   Sex       297 non-null    int64
#  2   CP        297 non-null    int64
#  3   Trestbps  297 non-null    int64
#  4   Chol      297 non-null    int64
#  5   fbs       297 non-null    int64
#  6   restecg   297 non-null    int64
#  7   Thalach   297 non-null    int64
#  8   Exang     297 non-null    int64
#  9   Oldpeak   297 non-null    float64
#  10  Slop      297 non-null    int64
#  11  CA        297 non-null    int64
#  12  thal      297 non-null    int64
#  13  Class     297 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 32.6 KB

# %%
print("Column names", df.columns.tolist())
# Out:
# Column names ['Age', 'Sex', 'CP', 'Trestbps', 'Chol', 'fbs', 'restecg', 'Thalach', 'Exang', 'Oldpeak', 'Slop', 'CA', 'thal', 'Class']

# %%
col = input("Enter column name: ")
df[col].value_counts()
# Out:
# Enter column name: Class
# Class
# 0    160
# 1     54
# 2     35
# 3     35
# 4     13
# Name: count, dtype: int64

# %%
df[col].isnull().sum()
# Out:
# 0

# %%
df[col].isna().sum()
# Out:
# 0

# %%
df[col].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
len(df[col])
# Out:
# 297

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=df, x= col)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(5,4))
df[col].value_counts().plot(kind='bar')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(5,4))
df[col].value_counts().plot(kind='pie', autopct="%1.1f")
plt.title("Pie Chart")
plt.grid(True)
plt.show()
